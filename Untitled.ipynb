# %%
import tifffile
import numpy as np

# %%
test = tifffile.imread("/stor/scratch/Ehrlich/Users/John/histocytometry/raw_images/20x_pan_DAPI_CD207_CD11c_XCR1_A/image.tif")

# %%
x_dim, y_dim = test.shape[1:3]

# %%
for i in range(400, 500):
    print("x_dim: " + str(i))
    print(str(x_dim/i))
    print("y_dim: " + str(i))
    print(str(y_dim/i))
# Out:
# x_dim: 400
# 42.3825
# y_dim: 400
# 32.755
# x_dim: 401
# 42.276807980049874
# y_dim: 401
# 32.67331670822943
# x_dim: 402
# 42.17164179104478
# y_dim: 402
# 32.592039800995025
# x_dim: 403
# 42.06699751861042
# y_dim: 403
# 32.511166253101734
# x_dim: 404
# 41.96287128712871
# y_dim: 404
# 32.43069306930693
# x_dim: 405
# 41.85925925925926
# y_dim: 405
# 32.35061728395062
# x_dim: 406
# 41.75615763546798
# y_dim: 406
# 32.27093596059113
# x_dim: 407
# 41.65356265356265
# y_dim: 407
# 32.19164619164619
# x_dim: 408
# 41.5514705882353
# y_dim: 408
# 32.11274509803921
# x_dim: 409
# 41.44987775061125
# y_dim: 409
# 32.034229828850854
# x_dim: 410
# 41.34878048780488
# y_dim: 410
# 31.95609756097561
# x_dim: 411
# 41.24817518248175
# y_dim: 411
# 31.878345498783457
# x_dim: 412
# 41.148058252427184
# y_dim: 412
# 31.800970873786408
# x_dim: 413
# 41.04842615012107
# y_dim: 413
# 31.723970944309926
# x_dim: 414
# 40.94927536231884
# y_dim: 414
# 31.647342995169083
# x_dim: 415
# ...
